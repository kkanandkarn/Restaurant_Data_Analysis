# %% [markdown]
# <a href="https://colab.research.google.com/github/kkanandkarn/Restaurant_Data_Analysis/blob/main/Restaurant_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading Dataset

# %%
restra = pd.read_csv("tips.csv")

# %%
restra
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # Checking if NAN value is present in any column.

# %%
restra.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %% [markdown]
# # Finding correlation

# %%
restra.corr()
# Out:
# <ipython-input-9-f6bb09a8e807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   restra.corr()
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %% [markdown]
# # Checking the classes of categorical values

# %%
restra.sex.unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
restra.smoker.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
restra.day.unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
restra.time.unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
restra['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %% [markdown]
# # Preparing data for mathematical calculations or Machine Learning.

# %%
restra
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
restra1 = restra

# %%
restra1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
restra1.sex.unique()
# Out:
# array([0, 1])

# %%
restra1.sex.map({'Female':0, 'Male': 1})
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 239    1
# 240    0
# 241    1
# 242    1
# 243    0
# Name: sex, Length: 244, dtype: int64

# %%
restra1.sex = restra1.sex.map({'Female':0, 'Male': 1})

# %%
restra1
# Out:
#      total_bill   tip  sex smoker   day    time  size
# 0         16.99  1.01    0     No   Sun  Dinner     2
# 1         10.34  1.66    1     No   Sun  Dinner     3
# 2         21.01  3.50    1     No   Sun  Dinner     3
# 3         23.68  3.31    1     No   Sun  Dinner     2
# 4         24.59  3.61    0     No   Sun  Dinner     4
# ..          ...   ...  ...    ...   ...     ...   ...
# 239       29.03  5.92    1     No   Sat  Dinner     3
# 240       27.18  2.00    0    Yes   Sat  Dinner     2
# 241       22.67  2.00    1    Yes   Sat  Dinner     2
# 242       17.82  1.75    1     No   Sat  Dinner     2
# 243       18.78  3.00    0     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
restra1.smoker.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
restra1.smoker = restra1.smoker.map({"No":0, "Yes": 1})

# %%
restra1
# Out:
#      total_bill   tip  sex  smoker   day    time  size
# 0         16.99  1.01    0       0   Sun  Dinner     2
# 1         10.34  1.66    1       0   Sun  Dinner     3
# 2         21.01  3.50    1       0   Sun  Dinner     3
# 3         23.68  3.31    1       0   Sun  Dinner     2
# 4         24.59  3.61    0       0   Sun  Dinner     4
# ..          ...   ...  ...     ...   ...     ...   ...
# 239       29.03  5.92    1       0   Sat  Dinner     3
# 240       27.18  2.00    0       1   Sat  Dinner     2
# 241       22.67  2.00    1       1   Sat  Dinner     2
# 242       17.82  1.75    1       0   Sat  Dinner     2
# 243       18.78  3.00    0       0  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
restra1.day.unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
restra1.day = restra1.day.map({"Sun":0, "Sat":1,"Thur": 2, "Fri": 3})

# %%
restra1
# Out:
#      total_bill   tip  sex  smoker  day    time  size
# 0         16.99  1.01    0       0    0  Dinner     2
# 1         10.34  1.66    1       0    0  Dinner     3
# 2         21.01  3.50    1       0    0  Dinner     3
# 3         23.68  3.31    1       0    0  Dinner     2
# 4         24.59  3.61    0       0    0  Dinner     4
# ..          ...   ...  ...     ...  ...     ...   ...
# 239       29.03  5.92    1       0    1  Dinner     3
# 240       27.18  2.00    0       1    1  Dinner     2
# 241       22.67  2.00    1       1    1  Dinner     2
# 242       17.82  1.75    1       0    1  Dinner     2
# 243       18.78  3.00    0       0    2  Dinner     2
#
# [244 rows x 7 columns]

# %%
restra1.time.unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
restra1.time = restra1.time.map({"Dinner":0, "Lunch": 1})

# %%
restra1
# Out:
#      total_bill   tip  sex  smoker  day  time  size
# 0         16.99  1.01    0       0    0     0     2
# 1         10.34  1.66    1       0    0     0     3
# 2         21.01  3.50    1       0    0     0     3
# 3         23.68  3.31    1       0    0     0     2
# 4         24.59  3.61    0       0    0     0     4
# ..          ...   ...  ...     ...  ...   ...   ...
# 239       29.03  5.92    1       0    1     0     3
# 240       27.18  2.00    0       1    1     0     2
# 241       22.67  2.00    1       1    1     0     2
# 242       17.82  1.75    1       0    1     0     2
# 243       18.78  3.00    0       0    2     0     2
#
# [244 rows x 7 columns]

# %%
restra1.corr()
# Out:
#             total_bill       tip       sex    smoker       day      time  \
# total_bill    1.000000  0.675734  0.144877  0.085721 -0.175312 -0.183118
# tip           0.675734  1.000000  0.088862  0.005929 -0.138947 -0.121629
# sex           0.144877  0.088862  1.000000  0.002816 -0.215374 -0.205231
# smoker        0.085721  0.005929  0.002816  1.000000  0.170818 -0.054921
# day          -0.175312 -0.138947 -0.215374  0.170818  1.000000  0.670470
# time         -0.183118 -0.121629 -0.205231 -0.054921  0.670470  1.000000
# size          0.598315  0.489299  0.086195 -0.133178 -0.211750 -0.103411
#
#                 size
# total_bill  0.598315
# tip         0.489299
# sex         0.086195
# smoker     -0.133178
# day        -0.211750
# time       -0.103411
# size        1.000000

# %% [markdown]
# # Extracting Useful Information
#
# ---
#
#
#
# ---
#
#
#
# # How many Male came to my restaurant ?

# %%
len(restra1[restra1.sex==1])
# Out:
# 157

# %% [markdown]
# # How many of those men were smokers ?

# %%
len(restra1[(restra1.sex==1)&(restra1.smoker == 1)])
# Out:
# 60

# %% [markdown]
# # Simillarly how many Female came to my restaurant ?

# %%
len(restra1[restra1.sex==0])
# Out:
# 87

# %% [markdown]
# # And how many of those women were smokers ?

# %%
len(restra1[(restra1.sex==0)&(restra1.smoker == 1)])
# Out:
# 33

# %%
# Count the number of males and females
male_count = len(restra1[restra1.sex == 1])
female_count = len(restra1[restra1.sex == 0])

# Create a bar chart
categories = ['Male', 'Female']
counts = [male_count, female_count]

plt.bar(categories, counts)
plt.title('Count of Customers by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Calculating the percentage of Male Smokers and Female smokers

# %%
Male_smokers_per = int((60/157)*100)
Female_smokers_per = int((33/87)*100)
print("Percentage of Male smokers:", Male_smokers_per, "%")
print("Percentage of Female smokers:", Female_smokers_per, "%")
# Out:
# Percentage of Male smokers: 38 %
# Percentage of Female smokers: 37 %

# %%
# Create a bar chart
categories = ['Male', 'Female']
percentages = [Male_smokers_per, Female_smokers_per]

plt.bar(categories, percentages)
plt.title('Percentage of Smokers by Gender')
plt.xlabel('Gender')
plt.ylabel('Percentage')
plt.show()

# %% [markdown]
# # How much money we have earned from the total bill ?

# %%
total_money_earned = sum(restra1.total_bill)
print("Money earned for total bill is: ", total_money_earned)
# Out:
# Money earned for total bill is:  4827.770000000001

# %% [markdown]
# # I am interested to know that how many females came to my restaurant on saturday night ?

# %%
len(restra1[(restra1.sex==0)&(restra1.day==1)&(restra1.time==0)])
# Out:
# 28

# %% [markdown]
# # Simillarly I want to know that how many Males came to my restaurant on saturday night ?

# %%
len(restra1[(restra1.sex==1)&(restra1.day==1)&(restra1.time==0)])
# Out:
# 59

# %%
# Count the number of females and males on Saturday night
female_count = len(restra1[(restra1.sex == 0) & (restra1.day == 1) & (restra1.time == 0)])
male_count = len(restra1[(restra1.sex == 1) & (restra1.day == 1) & (restra1.time == 0)])

# Create a bar chart
categories = ['Female', 'Male']
counts = [female_count, male_count]

plt.bar(categories, counts)
plt.title('Count of Customers on Saturday Night')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # I Want to Know who gave the highest tip ?

# %%
# Highest tip
Female_htip = sum(restra1.tip[restra1.sex==0])
Male_htip = sum(restra1.tip[restra1.sex==1])

print("Highest tip given by Women is: ", Female_htip)
print("Highest tip given by Men is: ", Male_htip)

# Maximum tip
Female_mtip = max(restra1.tip[restra1.sex==0])
Male_mtip = max(restra1.tip[restra1.sex==1])

print("\nMaximum tip given by Women is: ", Female_mtip)
print("Maximum tip given by Men is: ", Male_mtip)
# Out:
# Highest tip given by Women is:  246.51
# Highest tip given by Men is:  485.0700000000001
#
# Maximum tip given by Women is:  6.5
# Maximum tip given by Men is:  10.0

# %%
# Calculate the highest tip and maximum tip given by women and men
Female_htip = sum(restra1.tip[restra1.sex == 0])
Male_htip = sum(restra1.tip[restra1.sex == 1])
Female_mtip = max(restra1.tip[restra1.sex == 0])
Male_mtip = max(restra1.tip[restra1.sex == 1])

# Set the data and labels
categories = ['Female', 'Male']
highest_tips = [Female_htip, Male_htip]
maximum_tips = [Female_mtip, Male_mtip]

# Set the positions of the bars
bar_width = 0.35
r1 = np.arange(len(categories))

# Create a grouped horizontal bar chart
plt.barh(r1, highest_tips, height=bar_width, label='Highest Tip', color='red')
plt.barh(r1, maximum_tips, height=bar_width, label='Maximum Tip', color='blue', alpha=0.7)

# Add labels, title, and legend
plt.xlabel('Amount')
plt.ylabel('Gender')
plt.title('Tips by Gender')
plt.yticks(r1, categories)
plt.legend()

# Add values on the bars
for i, v in enumerate(highest_tips):
    plt.text(v, i, str(v), color='black', va='center')
for i, v in enumerate(maximum_tips):
    plt.text(v, i, str(v), color='black', va='center')

# Display the chart
plt.show()

# %%
# Maximum tip
Female_mintip = min(restra1.tip[restra1.sex==0])
Male_mintip = min(restra1.tip[restra1.sex==1])

print("Minimum tip given by Women is: ", Female_mintip)
print("Minimum tip given by Men is: ", Male_mintip)
# Out:
# Minimum tip given by Women is:  1.0
# Minimum tip given by Men is:  1.0

# %% [markdown]
# # I am to see the data of the customer who gave highest tip

# %%
print("Data of Male who give highest tip\n")
restra1[restra1.tip==Male_mtip]
# Out:
# Data of Male who give highest tip
#      total_bill   tip  sex  smoker  day  time  size
# 170       50.81  10.0    1       1    1     0     3

# %%
print("Data of Female who give highest tip\n")
restra1[(restra1.tip==6.5)&(restra1.sex==0)]
# Out:
# Data of Female who give highest tip
#      total_bill  tip  sex  smoker  day  time  size
# 214       28.17  6.5    0       1    1     0     3

# %% [markdown]
# # Total bill amount per day.

# %%
df = pd.read_csv('tips.csv')

# %%
total_bill_earned = sum(restra1.total_bill)
print("Total bill eared: ", total_bill_earned)
# Out:
# Total bill eared:  4827.770000000001

# %% [markdown]
# # Sum of total_bills per day

# %%
df.groupby(by=['day']).total_bill.agg(['sum'])
# Out:
#           sum
# day
# Fri    325.88
# Sat   1778.40
# Sun   1627.16
# Thur  1096.33

# %%
# Calculate the sum of total bills grouped by day
df_grouped = df.groupby(by=['day']).total_bill.agg(['sum'])


# Create a pie chart
labels = df_grouped.index
values = df_grouped['sum']

plt.pie(values, labels=labels, autopct='%1.1f%%', startangle=90)
plt.title('Total Bills by Day')

# Display the chart
plt.show()

# %% [markdown]
# # Analysing data for predications.

# %%
df.groupby(by=['day']).total_bill.agg(['sum','max','min','count'])
# Out:
#           sum    max   min  count
# day
# Fri    325.88  40.17  5.75     19
# Sat   1778.40  50.81  3.07     87
# Sun   1627.16  48.17  7.25     76
# Thur  1096.33  43.11  7.51     62

# %%
df.groupby(by=['day','time']).total_bill.agg(['sum','max','min','count'])
# Out:
#                  sum    max    min  count
# day  time
# Fri  Dinner   235.96  40.17   5.75     12
#      Lunch     89.92  16.27   8.58      7
# Sat  Dinner  1778.40  50.81   3.07     87
# Sun  Dinner  1627.16  48.17   7.25     76
# Thur Dinner    18.78  18.78  18.78      1
#      Lunch   1077.55  43.11   7.51     61

# %%
df.groupby(by=['day','time', 'smoker']).total_bill.agg(['sum','max','min','count'])
# Out:
#                         sum    max    min  count
# day  time   smoker
# Fri  Dinner No        57.70  22.75  12.46      3
#             Yes      178.26  40.17   5.75      9
#      Lunch  No        15.98  15.98  15.98      1
#             Yes       73.94  16.27   8.58      6
# Sat  Dinner No       884.78  48.33   7.25     45
#             Yes      893.62  50.81   3.07     42
# Sun  Dinner No      1168.88  48.17   8.77     57
#             Yes      458.28  45.35   7.25     19
# Thur Dinner No        18.78  18.78  18.78      1
#      Lunch  No       751.31  41.19   7.51     44
#             Yes      326.24  43.11  10.34     17

# %% [markdown]
# # How many people visited to the restaurant in total?

# %%
df.size.sum()
# Out:
# 1708
